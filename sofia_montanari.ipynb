# %% [markdown]
# # [EXERCISE 1]
#
# SOFIA MONTANARI UNIVERSIDAD AUSTRAL smontanari@maul.austral.edu.ar
# ![WhatsApp Image 2024-04-19 at 2.51.46 PM.jpeg](attachment:57d39f79-2cba-4842-8b07-5e0cf05b36c2.jpeg)
# Its a picture i took 2 years ago at a concert.

# %% [markdown]
# # [Exercise 5]

# %% [markdown]
# # SUM

# %%
a=3
b=7
print(a+b)
# Out:
# 10

# %% [markdown]
# # SUBSTRACTION

# %%
print(a-b)
# Out:
# -4

# %% [markdown]
# # MULTIPLICATION

# %%
 print(a*b)
# Out:
# 21

# %% [markdown]
# # DIVISION

# %%
print(a/b)
# Out:
# 0.42857142857142855
